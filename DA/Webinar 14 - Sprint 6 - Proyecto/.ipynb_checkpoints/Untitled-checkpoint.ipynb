# %% [markdown]
# # Proyecto integrado - Modulo 1

# %% [markdown]
# ## Paso 1

# %% [markdown]
# ### Librerías

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Carga del dataset

# %%
df = pd.read.csv....

# %% [markdown]
# ## Paso 2

# %% [markdown]
# ## Paso 3

# %% [markdown]
# ## Paso 4

# %% [markdown]
# ## Paso 5

# %% [markdown]
# ## Paso 6

# %% [markdown]
# Esta es una conclusion.
