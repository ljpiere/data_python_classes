# %% [markdown]
# # Webinar 12: Sprint 3: Grammy Nominees & Winners (1958–2024)
# Bienvenidos a esta sesión de análisis exploratorio de datos.
#
# ## Objetivos
# - Realizar un EDA a un dataset.
# - Corregir nombres de las columnas.
# - Imputar valores vacios y duplicados.
# - Proponer agrupaciones de atributos para realizar análisis.

# %% [markdown]
# <div style="text-align: center">
#     <img src="https://raw.githubusercontent.com/ljpiere/data_python_classes/main/DA_DS/images/3_12.jpg" width="300">
# </div>

# %% [markdown]
# ## 1. Importación de librerías y carga de datos
# Primero, importaremos pandas y cargaremos el dataset:
# - **¿Por qué pandas?** Porque es la biblioteca estándar de Python para manipulación de datos.

# %%
import pandas as pd

# Cargar el dataset
df = pd.read_csv("https://raw.githubusercontent.com/ljpiere/data_python_classes/main/DA_DS/datasets/Grammy_Nominees_Winners_1958to2024.csv")
df.head()
# Out:
#    Unnamed: 0  Year  Ceremony  Award ID Award Type  \
# 0           0  1958         1       587       Work
# 1           1  1958         1       587       Work
# 2           2  1958         1       587       Work
# 3           3  1958         1       587       Work
# 4           4  1958         1       587       Work
#
#                     Award Name                                   Work  \
# 0  Best Recording For Children       Childrens' Marching Song (Album)
# 1  Best Recording For Children  Mommy, Give Me A Drinka Water (Album)
# 2  Best Recording For Children                       The Witch Doctor
# 3  Best Recording For Children                         Tubby The Tuba
# 4  Best Recording For Children               Fun In Shariland (Album)
#
#                            Nominee  Winner
# 0                  Cyril Stapleton   False
# 1                       Danny Kaye   False
# 2  David Seville And The Chipmunks   False
# 3                      Jose Ferrer   False
# ...

# %% [markdown]
# **Pregunta al aire:** ¿Qué observas en la estructura de las primeras filas?

# %% [markdown]
# ## 2. EDA básico (sin gráficas)
# Veremos la información general y los valores faltantes.
# ### 2.1 info()
# - Muestra columnas, tipos y conteo de valores no nulos.
# - **Ejercicio:** Identifica cuántas columnas son numéricas y cuántas categóricas.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25305 entries, 0 to 25304
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  25305 non-null  int64
#  1   Year        25305 non-null  int64
#  2   Ceremony    25305 non-null  int64
#  3   Award ID    25305 non-null  int64
#  4   Award Type  25305 non-null  object
#  5   Award Name  25305 non-null  object
#  6   Work        24412 non-null  object
#  7   Nominee     25305 non-null  object
#  8   Winner      25305 non-null  bool
# dtypes: bool(1), int64(4), object(4)
# memory usage: 1.6+ MB

# %% [markdown]
# ### 2.2 describe()
# - Estadísticos descriptivos.
# - **Pregunta:** ¿Cuál es el rango intercuartílico (IQR) de la duración de canciones nominadas?

# %%
df.describe()
# Out:
#          Unnamed: 0          Year      Ceremony      Award ID
# count  25305.000000  25305.000000  25305.000000  25305.000000
# mean   12652.000000   1995.793756     38.793756    672.282988
# std     7305.068617     17.959109     17.959109    120.804628
# min        0.000000   1958.000000      1.000000    584.000000
# 25%     6326.000000   1982.000000     25.000000    614.000000
# 50%    12652.000000   1998.000000     41.000000    661.000000
# 75%    18978.000000   2010.000000     53.000000    701.000000
# max    25304.000000   2024.000000     67.000000   2432.000000

# %% [markdown]
# ### 2.3 isnull().sum()
# - Cuenta nulos por columna.
# - **Ejercicio:** Anota qué columnas tienen más del 10% de valores faltantes.

# %%
null_pct = df.isnull().sum() / len(df) * 100
null_pct[null_pct > 10]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Year            0
# Ceremony        0
# Award ID        0
# Award Type      0
# Award Name      0
# Work          893
# Nominee         0
# Winner          0
# dtype: int64

# %% [markdown]
# ## 3. Filtros básicos
# ### 3.1 Filtrar ganadores
# - `df[df['Winner'] == True]`
# - **Pregunta:** ¿Qué artista tiene más premios Grammy en este dataset?

# %%
winners = df[df['Winner'] == True]
winners.groupby('Award Name')['Winner'].count()
# Out:
# Award Name
# Album Notes                                                                           2
# Album Of Best Original Score Written For A Motion Picture Or A Television Special     4
# Album Of The Year                                                                    65
# Album Of The Year (Other Than Classical)                                              3
# Album Of The Year - Classical                                                         5
#                                                                                      ..
# Tropical Latin Album                                                                  2
# Urban/Alternative Performance                                                         1
# Video Of The Year                                                                     2
# World Music Album                                                                     1
# ...

# %% [markdown]
# ### 3.2 Filtrar por categoría
# - Ejemplo: Record of the Year
# - **Ejercicio:** Filtra la categoría 'Album of the Year' y cuenta el número de nominaciones.

# %%
album_nom = df[df['Award Name'] == 'Album of the Year']
album_nom.shape[0]
# Out:
# 0

# %% [markdown]
# ### 3.3 Filtrar por año
# - Ejercicio interactivo: ¿Cuántas nominaciones hubo en 2020?

# %%
df[df['Year'] == 2020].shape[0]
# Out:
# 429

# %% [markdown]
# ## 4. Cambios de nombres de columna
# Estandarizamos nombres para facilitar el análisis.
# ### 4.1 Usando un bucle for
# - Convertir a minúsculas y snake_case.
# - **¿Por qué estandarizar?** Evita errores de referencia.

# %%
for col in df.columns:
    new = col.strip().lower().replace(' ', '_').replace('/', '_')
    df.rename(columns={col: new}, inplace=True)
df.columns
# Out:
# Index(['unnamed:_0', 'year', 'ceremony', 'award_id', 'award_type',
#        'award_name', 'work', 'nominee', 'winner'],
#       dtype='object')

# %% [markdown]
# ### 4.2 Verificación rápida
# - Ejercicio: Muestra las columnas que ahora contienen 'year' o 'winner'.

# %%
columnas_filtradas = []
for col in df.columns:
    if 'year' in col or 'winner' in col:
        columnas_filtradas.append(col)

# %% [markdown]
# ## 5. Búsqueda e imputación de vacíos y nulos
# ### 5.1 Identificación de nulos
# - `df.isnull().sum()`
# - **Ejercicio:** Lista las 3 columnas con más nulos.

# %%
df.isnull().sum().sort_values(ascending=False).head(3)

# %% [markdown]
# ### 5.2 Imputación con forward-fill y backward-fill
# - Ejercicio: ¿Qué sucede si aplicas `ffill` y luego `bfill`? Comprueba los cambios.

# %%
df_ffill = df.fillna(method='ffill').fillna(method='bfill')
df_ffill.isnull().sum()

# %% [markdown]
# ### 5.3 Imputación con valor fijo
# - Para columnas categóricas como 'nominee', usaremos 'Unknown'.
# - **Ejercicio:** Imputa 'Unknown' en 'nominee'.

# %%
df_ffill['nominee'].fillna('Unknown', inplace=True)
df_ffill['nominee'].isnull().sum()

# %% [markdown]
# ## 6. `groupby` con funciones
# Encapsulamos lógicas comunes en funciones reutilizables.

# %% [markdown]
# ### 6.1 Conteo de ganadores por año
# - Define `count_winners_by_year(df)` que devuelva un Series.

# %%
df[df['nominee'] == 'Taylor Swift'].head()
# Out:
#        unnamed:_0  year  ceremony  award_id award_type  \
# 17204       17204  2007        50       630    Nominee
# 18202       18202  2009        52       604       Work
# 18231       18231  2009        52       610       Work
# 18294       18294  2009        52       627       Work
# 18301       18301  2009        52       628       Work
#
#                                   award_name                work  \
# 17204                        Best New Artist                 NaN
# 18202  Best Female Country Vocal Performance         White Horse
# 18231                     Best Country Album            Fearless
# 18294                     Record Of The Year  You Belong With Me
# 18301                      Album Of The Year            Fearless
#
#             nominee  winner
# 17204  Taylor Swift   False
# 18202  Taylor Swift    True
# 18231  Taylor Swift    True
# 18294  Taylor Swift   False
# 18301  Taylor Swift    True

# %%
df.groupby('year')['winner'].count()
# Out:
# year
# 1958    142
# 1959    172
# 1960    239
# 1961    202
# 1962    239
#        ...
# 2020    429
# 2021    462
# 2022    481
# 2023    485
# 2024    492
# Name: winner, Length: 67, dtype: int64

# %%
df_dos = df[df['nominee'] == 'Taylor Swift']
df_dos.head()
# Out:
#        unnamed:_0  year  ceremony  award_id award_type  \
# 17204       17204  2007        50       630    Nominee
# 18202       18202  2009        52       604       Work
# 18231       18231  2009        52       610       Work
# 18294       18294  2009        52       627       Work
# 18301       18301  2009        52       628       Work
#
#                                   award_name                work  \
# 17204                        Best New Artist                 NaN
# 18202  Best Female Country Vocal Performance         White Horse
# 18231                     Best Country Album            Fearless
# 18294                     Record Of The Year  You Belong With Me
# 18301                      Album Of The Year            Fearless
#
#             nominee  winner
# 17204  Taylor Swift   False
# 18202  Taylor Swift    True
# 18231  Taylor Swift    True
# 18294  Taylor Swift   False
# 18301  Taylor Swift    True

# %%
def count_winners_by_year(nominado, anio):
    df_dos = df[df['nominee'] == nominado]
    df_tres = df_dos[df_dos['year'] == anio]
    conteo = df_tres.groupby('year')['winner'].count()
    return conteo
    

count_winners_by_year("Taylor Swift", "2020")
# Out:
# Series([], Name: winner, dtype: int64)

# %% [markdown]
# **Discusión:** ¿Por qué agrupar antes de filtrar podría cambiar el resultado?

# %% [markdown]
# ### 6.2 Promedio de nominaciones por categoría
# - Define `avg_nominees_per_category(df)` y explica su lógica.

# %%
def avg_nominees_per_category(df):
    counts = df.groupby('category')['nominee'].count()
    return counts.mean()

avg_nominees_per_category(df_ffill)

# %% [markdown]
# ## Reto final
# 1. **Pregunta abierta:** ¿Qué otras columnas crees que podríamos analizar con groupby? Propón dos ejemplos.
# 2. **Desafío práctico:** Combina filtros y groupby para encontrar el artista con mayor número de nominaciones en los últimos 5 años.
