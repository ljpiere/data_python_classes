# %% [markdown]
# # Ejercicios de corrección: Identifica y corrige errores comunes

# %% [markdown]
# ## Paso 1: Limpieza inicial de un registro de cliente
# **Errores comunes a detectar:**
# - errores: no strip(), acceso por índices equivocados, no conversión a int
#
# **Ejercicio práctico:** Corrige el siguiente código para manejar los errores comunes:
# ```python
# registro = [' Juan ', 'Doe', ' 30 ']
# # Solución esperada: ['Juan', 'Doe', 30]
# ```

# %% [markdown]
# ## Paso 2: Convertir las categorías a minúsculas
# **Errores comunes a detectar:**
# - errores: aplicar lower a lista, no reasignar resultado, ignorar mayúsculas
#
# **Ejercicio práctico:** Corrige el siguiente código para manejar los errores comunes:
# ```python
# categorias = ['VENTAS', 'MARKETING', 'RRHH']
# # Solución esperada: ['ventas', 'marketing', 'rrhh']
# ```

# %% [markdown]
# ## Paso 3: Limpieza completa de un usuario
# **Errores comunes a detectar:**
# - errores: modificar original, nombre de función mal, indentación
#
# **Ejercicio práctico:** Corrige el siguiente código para manejar los errores comunes:
# ```python
# def limpiar_usuario(usuario):
#     # usuario es lista [' Ana ', ' 28 ']
#     # Retornar ['Ana', 28]
#     pass
# ```

# %% [markdown]
# ## Paso 4: Limpieza de toda la base de usuarios
# **Errores comunes a detectar:**
# - errores: olvidar return, reassign en loop, no manejar None
#
# **Ejercicio práctico:** Corrige el siguiente código para manejar los errores comunes:
# ```python
# usuarios = [[' Juan ', 'Doe', '30'], ['Luisa','Perez','25']]
# # Aplicar función limpiar_usuario a cada uno
# ```

# %% [markdown]
# ## Paso 5: Calcular ingresos totales
# **Errores comunes a detectar:**
# - errores: usar sum en strings, índice equivocado, no inicializar acumulador
#
# **Ejercicio práctico:** Corrige el siguiente código para manejar los errores comunes:
# ```python
# gastos = ['120.5', '89.99', '45']
# # Sumar y devolver total como float
# ```

# %% [markdown]
# ## Paso 6: Usuarios menores de 30 años
# **Errores comunes a detectar:**
# - errores: usar <= en vez de <, confundir and/or, no chequear tipo
#
# **Ejercicio práctico:** Corrige el siguiente código para manejar los errores comunes:
# ```python
# usuarios = [{'name':'Ana','age':'25'}, {'name':'Luis','age':30}]
# # Filtrar age < 30
# ```

# %% [markdown]
# ## Paso 7: Jóvenes con alto gasto
# **Errores comunes a detectar:**
# - errores: condición mal, olvidar ordenar, lista vacía con max()
#
# **Ejercicio práctico:** Corrige el siguiente código para manejar los errores comunes:
# ```python
# gastos = [{'name':'Ana','age':22,'spend':100}, {'name':'Luis','age':28,'spend':200}, {'name':'Eva','age':31,'spend':150}]
# # Máximo spend para age<25
# ```

# %% [markdown]
# ## Paso 8: Usuarios que compraron ropa
# **Errores comunes a detectar:**
# - errores: sensibilidad de mayúsculas, espacios extras, no devolver lista vacía
#
# **Ejercicio práctico:** Corrige el siguiente código para manejar los errores comunes:
# ```python
# compras = ['alimentos','ropa','electrónicos']
# # Filtrar solo 'ropa'
# ```

# %% [markdown]
# ## Paso 9: Función con filtro por categoría
# **Errores comunes a detectar:**
# - errores: función no definida, olvidar return, falta documentación
#
# **Ejercicio práctico:** Corrige el siguiente código para manejar los errores comunes:
# ```python
# def filter_by_category(cat, items):
#     # items es lista de strings
#     pass
#
# # Uso: filter_by_category('deporte', ['deporte','ocio','cultura'])
# ```

# %% [markdown]
# ## Paso 10: Buenas prácticas y depuración
# **Errores comunes a detectar:**
# - errores: sin docstrings, sin manejo de excepciones, sin pruebas límite
#
# **Ejercicio práctico:** Corrige el siguiente código para manejar los errores comunes:
# ```python
# def dividir(a, b):
#     return a / b
#
# # Añadir docstring y manejo de ZeroDivisionError
# ```
